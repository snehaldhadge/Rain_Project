# %%
import pandas as pd
import numpy as np

# %%
cdata = pd.read_excel('Companies_BVDid-1.xlsx',sheet_name='Results',na_values=np.NaN)

# %%
cdata
# Out:
#      Unnamed: 0            Company name Latin alphabet  \
# 0           1.0                          VOLKSWAGEN AG
# 1           2.0                       AMAZON.COM, INC.
# 2           3.0                             APPLE INC.
# 3           4.0           SAMSUNG ELECTRONICS CO.,LTD.
# 4           5.0                             DAIMLER AG
# ..          ...                                    ...
# 673       674.0          TONINO LAMBORGHINI HK LIMITED
# 674       675.0                      META LEBANON SARL
# 675       676.0                   GRUPO ILLICE 20 S.L.
# 676       677.0          VISTAJET AVIATION SERVICES SA
# 677       678.0  ARCHROMA HOLDINGS GMBH IN LIQUIDATION
#
#     Operating revenue (Turnover)\nm USD 2019  \
# 0                                     291926
# 1                                     280522
# 2                                     260174
# 3                                     198999
# 4                                     197165
# ...

# %%
df2 = pd.read_csv("Final_Projects_2020.csv")
# Out:
# //anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (3,6,9,10,11,13,15,17,19,26,30,34,36,40,41,42,43,44,45,47,48,49,50,51,53,54,55,58,59,60,61,62,63,64,65,66,67,68,69,70,71,72,73,74,75,78,79,80,82,84,85,87,89,91,93,95,97,98,99,100,101,103,104,105,106,107,108,110,111,112,113,114,115,116,117,118,119,120,121,122,123,124,125,126,127,128,129,130,131,132,133,135,149,150,151,250,251,253,254,255,256,257,258,259,260,261,262,263,264,265,266,267,268,269,270,271,272,273,274,275,276,277,278,279,280,281,282,283,284,285,286,287,288,289,290) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
selected_df = df2[df2['iBVDid'].isin(cdata['BvD ID number'])]
selected_df
# Out:
#         Unnamed: 0  Unnamed: 0.1  \
# 4                4             4
# 12              12            12
# 27              27            27
# 28              28            28
# 57              57            57
# ...            ...           ...
# 862120      862120         86866
# 862121      862121         86867
# 862122      862122         86868
# 862123      862123         86869
# 862124      862124         86874
#
#                                                 pheadline    pnumber ptype  \
# 4           Hilton Worldwide to open hotel in Agra, India  931655359   New
# 12      Takko Holding to open a clothing store in East...  774890903   New
# 27      Primark to open stores in the Northeast Megalo...  614089871   New
# 28          Hilton Worldwide to open hotel in Pune, India  596383059   New
# 57        Hilton Worldwide to open hotel in Jaipur, India  187667823   New
# ...                                                   ...        ...   ...
# ...

# %%
selected_df[['iBVDid','oper_turnover','adate']]
# Out:
#               iBVDid     oper_turnover       adate
# 4        US274384691              9735  2014-04-21
# 12      DE4250273629              n.a.  2014-11-28
# 27        GB00453448  4007.55120250118  2014-09-09
# 28       US274384691              9735  2014-04-21
# 57       US274384691              9735  2014-04-21
# ...              ...               ...         ...
# 862120  IN0008565743              n.a.         NaN
# 862121  IN0008565743              n.a.         NaN
# 862122  IN0008565743              n.a.         NaN
# 862123  IN0008565743              n.a.         NaN
# 862124  IN0008565743              n.a.         NaN
#
# [13964 rows x 3 columns]

# %%
selected_df[selected_df['iBVDid'] == 'US274384691'][['adate','rdate','oper_turnover']]
# Out:
#              adate       rdate oper_turnover
# 4       2014-04-21  2014-04-21          9735
# 28      2014-04-21  2014-04-21          9735
# 57      2014-04-21  2014-04-21          9735
# 473639  2014-05-18  2014-05-18          9735
# 534718  2015-12-16  2015-12-16         10502
# ...            ...         ...           ...
# 861232         NaN  2019-03-01          8906
# 861294         NaN  2019-02-27          8906
# 861296         NaN  2019-02-27          8906
# 861298         NaN  2019-02-27          8906
# 862068         NaN  2019-01-08          8906
#
# [335 rows x 3 columns]

# %%
cdata[cdata["BvD ID number"] == 'US274384691' ]
# Out:
#     Unnamed: 0     Company name Latin alphabet  \
# 95        96.0  HILTON WORLDWIDE HOLDINGS INC.
#
#    Operating revenue (Turnover)\nm USD 2019  \
# 95                                     9452
#
#    Operating revenue (Turnover)\nm USD 2018  \
# 95                                     8906
#
#    Operating revenue (Turnover)\nm USD 2017  \
# 95                                     8131
#
#    Operating revenue (Turnover)\nm USD 2016  \
# 95                                     6576
#
#    Operating revenue (Turnover)\nm USD 2015  \
# 95                                     7133
#
#    Operating revenue (Turnover)\nm USD 2014  \
# 95                                    10502
#
#    Operating revenue (Turnover)\nm USD 2013  \
# 95                                     9735
#
#    Operating revenue (Turnover)\nm USD 2012  ... Profit margin (%)\n2018  \
# 95                                     9276  ...                  12.104
#
# ...

# %%
selected_df[selected_df['iBVDid'] == 'IN0008565743'][['adate','rdate','oper_turnover']]
# Out:
#              adate       rdate     oper_turnover
# 592130  2016-01-12  2016-01-12  4.96074634892642
# 613961  2017-05-20  2017-05-20  21.7088751866925
# 616942  2018-12-18  2018-12-18              n.a.
# 616948  2018-12-18  2018-12-18              n.a.
# 616949  2018-12-18  2018-12-18              n.a.
# 616959  2018-12-18  2018-12-18              n.a.
# 616994  2018-12-18  2018-12-18              n.a.
# 617004  2018-12-18  2018-12-18              n.a.
# 620838  2018-10-15  2018-10-15              n.a.
# 620895  2018-10-15  2018-10-15              n.a.
# 620899  2018-10-15  2018-10-15              n.a.
# 622540  2018-09-20  2018-09-20              n.a.
# 622561  2018-09-20  2018-09-20              n.a.
# 622562  2018-09-20  2018-09-20              n.a.
# 622591  2018-09-20  2018-09-20              n.a.
# 627027  2018-06-20  2018-06-20              n.a.
# 627037  2018-06-20  2018-06-20              n.a.
# 627041  2018-06-20  2018-06-20              n.a.
# ...

# %%
cdata[cdata["BvD ID number"] == 'IN0008565743' ]
# Out:
#      Unnamed: 0   Company name Latin alphabet  \
# 399       400.0  ORAVEL STAYS PRIVATE LIMITED
#
#     Operating revenue (Turnover)\nm USD 2019  \
# 399                                     n.a.
#
#     Operating revenue (Turnover)\nm USD 2018  \
# 399                                     n.a.
#
#     Operating revenue (Turnover)\nm USD 2017  \
# 399                                     n.a.
#
#     Operating revenue (Turnover)\nm USD 2016  \
# 399                                  21.7089
#
#     Operating revenue (Turnover)\nm USD 2015  \
# 399                                  4.96075
#
#     Operating revenue (Turnover)\nm USD 2014  \
# 399                                     n.a.
#
#     Operating revenue (Turnover)\nm USD 2013  \
# 399                                     n.a.
#
#     Operating revenue (Turnover)\nm USD 2012  ... Profit margin (%)\n2018  \
# 399                                     n.a.  ...                    n.a.
#
# ...

# %%
selected_df[selected_df['iBVDid'] == 'GB00453448'][['adate','rdate','oper_turnover','IPO']]
# Out:
#              adate       rdate     oper_turnover  IPO
# 27      2014-09-09  2014-09-09  4007.55120250118  NaN
# 66      2014-12-19  2014-12-19  4007.55120250118  NaN
# 59215   2014-12-19  2014-12-19  4007.55120250118  NaN
# 59241   2014-12-19  2014-12-19  4007.55120250118  NaN
# 542609  2015-10-18  2015-10-18  4628.70263158548  NaN
# ...            ...         ...               ...  ...
# 856200         NaN  2018-11-07  4245.02090327024  NaN
# 856203         NaN  2018-11-07  4245.02090327024  NaN
# 856204         NaN  2018-11-07  4245.02090327024  NaN
# 860263         NaN  2019-05-06  4357.17558169293  NaN
# 860274         NaN  2019-05-06  4357.17558169293  NaN
#
# [83 rows x 4 columns]

# %%
cdata[cdata["BvD ID number"] == 'GB00453448' ]
# Out:
#      Unnamed: 0 Company name Latin alphabet  \
# 132       133.0      PRIMARK STORES LIMITED
#
#     Operating revenue (Turnover)\nm USD 2019  \
# 132                                  4205.03
#
#     Operating revenue (Turnover)\nm USD 2018  \
# 132                                  4357.18
#
#     Operating revenue (Turnover)\nm USD 2017  \
# 132                                  4245.02
#
#     Operating revenue (Turnover)\nm USD 2016  \
# 132                                  3816.28
#
#     Operating revenue (Turnover)\nm USD 2015  \
# 132                                  4467.81
#
#     Operating revenue (Turnover)\nm USD 2014  \
# 132                                   4628.7
#
#     Operating revenue (Turnover)\nm USD 2013  \
# 132                                  4007.55
#
#     Operating revenue (Turnover)\nm USD 2012  ... Profit margin (%)\n2018  \
# 132                                  3647.54  ...                   9.944
#
# ...
